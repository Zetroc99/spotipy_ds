# %%
import pandas as pd

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
name = 'The Weeknd'
results = sp.search(q='artist:' + name, type='track', limit=50)
results['tracks']['items']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Xyo4u8uXC1ZmMpatF05PJ'},
#      'href': 'https://api.spotify.com/v1/artists/1Xyo4u8uXC1ZmMpatF05PJ',
#      'id': '1Xyo4u8uXC1ZmMpatF05PJ',
#      'name': 'The Weeknd',
#      'type': 'artist',
#      'uri': 'spotify:artist:1Xyo4u8uXC1ZmMpatF05PJ'}],
#    'available_markets': ['AD',
#     'AE',
#     'AG',
#     'AL',
#     'AM',
#     'AO',
#     'AR',
#     'AT',
#     'AU',
#     'AZ',
#     'BA',
#     'BB',
#     'BD',
#     'BE',
#     'BF',
#     'BG',
#     'BH',
#     'BI',
#     'BJ',
#     'BN',
#     'BO',
#     'BR',
#     'BS',
#     'BT',
#     'BW',
#     'BY',
#     'BZ',
#     'CA',
#     'CD',
#     'CG',
#     'CH',
#     'CI',
#     'CL',
#     'CM',
#     'CO',
#     'CR',
#     'CV',
#     'CW',
#     'CY',
#     'CZ',
#     'DE',
#     'DJ',
#     'DK',
#     'DM',
#     'DO',
#     'DZ',
#     'EC',
#     'EE',
#     'EG',
#     'ES',
# ...

# %%
artist_name = []
track_name = []
track_popularity = []
track_id = []
for i in range(0,200,50):
    track_results = sp.search(q='artist:' + name, type='track', limit=50,offset=i)
    for i, t in enumerate(track_results['tracks']['items']):
        artist_name.append(t['artists'][0]['name'])
        track_name.append(t['name'])
        track_id.append(t['id'])
        track_popularity.append(t['popularity'])

# %%
track_df = pd.DataFrame({'artist_name' : artist_name, 'track_name' : track_name, 'track_id' : track_id, 'track_popularity' : track_popularity})
print(track_df.shape)
track_df
# Out:
# (200, 4)
#     artist_name           track_name                track_id  track_popularity
# 0    The Weeknd      Blinding Lights  0VjIjW4GlUZAMYd2vXMi3b                91
# 1    The Weeknd      Save Your Tears  5QO79kh1waicV47BqGRL3g                89
# 2    The Weeknd            The Hills  7fBv7CLKzipRk6EC6TWHOB                86
# 3    The Weeknd          Die For You  2Ch7LmS7r2Gy2kc64wv3Bz                84
# 4    The Weeknd              Starboy  7MXVkk9YMctZqd1Srtv4MB                86
# ..          ...                  ...                     ...               ...
# 195  The Weeknd  Heaven Or Las Vegas  3hDnFYwpnY0wONZDkYxUsj                49
# 196  The Weeknd                Faith  2QIbiBkgr2pepvCkmWi3Vn                51
# 197  The Weeknd  Belong To The World  3D7izPzeEcz7lBhcCZJccl                50
# 198  The Weeknd          Alone Again  3KQ1KVG2F8qAospksegrmZ                50
# 199  The Weeknd      Blinding Lights  0djfvA3c8AxxlQolu6zn6K                52
#
# ...

# %%
weeknd = '1Xyo4u8uXC1ZmMpatF05PJ'

results = sp.artist_albums(weeknd, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Dawn FM (Alternate World)
# Dawn FM (Alternate World)
# Dawn FM
# Dawn FM
# After Hours (Deluxe)
# After Hours (Deluxe)
# After Hours (Deluxe)
# After Hours (Deluxe)
# After Hours
# After Hours
# My Dear Melancholy,
# My Dear Melancholy,
# Starboy
# Starboy
# Beauty Behind The Madness
# Beauty Behind The Madness
# Beauty Behind The Madness
# Beauty Behind The Madness
# Kiss Land (Deluxe)
# Kiss Land
# Kiss Land (Deluxe MENA Version)
# Kiss Land
# Kiss Land
# Kiss Land
# Trilogy
# Trilogy
# Trilogy
# Echoes Of Silence (Original)
# Thursday (Original)
# House Of Balloons (Original)

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import spotipy
import sys
import pprint

username = 'zetroc_'

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace = True
user = sp.current_user_top_tracks()
pprint.pprint(user)
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/me/top/tracks with Params: {'time_range': 'medium_term', 'limit': 20, 'offset': 0} returned 403 due to None
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/miniforge3/envs/vision/lib/python3.8/site-packages/spotipy/client.py:245, in Spotify._internal_call(self, method, url, payload, params)
#     240 response = self._session.request(
#     241     method, url, headers=headers, proxies=self.proxies,
#     242     timeout=self.requests_timeout, **args
#     243 )
# --> 245 response.raise_for_status()
#     246 results = response.json()
#
# File ~/miniforge3/envs/vision/lib/python3.8/site-packages/requests/models.py:1022, in Response.raise_for_status(self)
#    1021 if http_error_msg:
# -> 1022     raise HTTPError(http_error_msg, response=self)
#
# ...
